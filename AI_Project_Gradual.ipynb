# %% [markdown]
# # AI B Project: comparing graduals from the 15th century

# %% [markdown]
# ## 1. Context

# %% [markdown]
# ### 1.1 Object of Interest
#
# ![Alt text](gradual.png "a title")

# %% [markdown]
# ### 1.2 Objective of the Project
#
# The objectives of this project are to:
#
# 1. Compare insular and German graduals
# 2. Examine whether generative AI can help in this investigation
# 3. Engage a general audience with the difference between graduals from the two different regions

# %%
import matplotlib
import tensorflow as tf
import keras
import sklearn
import seaborn

# %%
from IPython.display import Image

Image("german_gradual.jpg")
